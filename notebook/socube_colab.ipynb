# %%
#@title Mount google drive { display-mode: "form" }
mounted_path = "/content/drive/" #@param {type: "string"}
force_remount = False #@param {type: "boolean"}

from google.colab import drive
drive.mount(mounted_path, force_remount=force_remount)
# Out:
# Mounted at /content/drive/

# %%
#@title Install SoCube { display-mode: "form" }
# %pip install socube

# %%
#@title Run SoCube { display-mode: "form" }
from socube import main
home_dir = "/content/drive/MyDrive/project/SoCube/" #@param {type: "string"}
h5ad_input_file = "datasets/pbmc-1C-dm/pbmc-1C-dm[csc_sparse_matrix].h5ad" #@param {type: "string"}
multiprocess = True #@param {type: "boolean"}
device = "0" #@param {type: "string"}
validation = True #@param {type: "boolean"}
args = [
    "-i", home_dir + h5ad_input_file,
    "-o", home_dir,
    "--gpu-ids", device]
if validation:
    args.append("--enable-validation")
if multiprocess:
    args.append("--enable-multiprocess")
main(*args)
# Out:
# 2022-06-20 09:25:39,900 - Config - INFO - Load required modules
# 2022-06-20 09:25:40,035 - numexpr.utils - INFO - NumExpr defaulting to 2 threads.
# 2022-06-20 09:25:48,567 - root - INFO - Generating grammar tables from /usr/lib/python3.7/lib2to3/Grammar.txt
# 2022-06-20 09:25:48,593 - root - INFO - Generating grammar tables from /usr/lib/python3.7/lib2to3/PatternGrammar.txt
# 2022-06-20 09:25:49,364 - ParallelManager - INFO - Enter a multi-thread context
# 2022-06-20 09:25:49,643 - Preprocess - INFO - Load data
# 2022-06-20 09:25:50,994 - Generate - INFO - Generating doublet with ratio 1 and adj 1.0...
# 2022-06-20 09:25:51,006 - Pre-processing - INFO - Filter data
# 2022-06-20 09:25:51,617 - Generate - INFO - Writing dataset...
# 2022-06-20 09:25:51,652 - Generate - INFO - Train data created
# 2022-06-20 09:25:57,195 - SoPCACube - INFO - Current socube job config will be saved to /content/drive/MyDrive/project/SoCube/embedding/20220620-092548-671/config.json
# 2022-06-20 09:25:57,261 - SoPCACube - INFO - Standard data by z-score
# 2022-06-20 09:25:57,335 - SoPCACube - INFO - Normalize data by min-max scale
# 2022-06-20 09:25:57,437 - SoPCACube - INFO - Standard data saved
# 2022-06-20 09:25:57,563 - SoPCACube - INFO - Normalized data saved
# 2022-06-20 09:25:58,133 - SoPCACube - INFO - Write pca result to file
# 2022-06-20 09:25:58,139 - SoPCACube - INFO - Manifold learning by umap
# 2022-06-20 09:25:58,170 - SoPCACube - INFO - Gene pca data saved
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# 2022-06-20 09:26:21,686 - SoPCACube - INFO - JV alignment to grid
# 2022-06-20 09:26:21,774 - SoPCACube - INFO - Manifold 2d result saved
# 2022-06-20 09:26:41,154 - SoPCACube - INFO - Grid shape is (42, 43)
# 2022-06-20 09:26:41,169 - SoPCACube - INFO - Grid data saved
# 2022-06-20 09:26:41,171 - ParallelManager - INFO - Wait for 1 asynchronou task(s) finished
# 2022-06-20 09:26:41,175 - Post-processing - INFO - Processing data with log, std and feature minmax
# 2022-06-20 09:26:46,636 - Post-processing - INFO - Single channels data is tranforming
# 2022-06-20 09:26:46,666 - SoPCACube - INFO - Batch transform 7905 samples
# Transform:   0%|          | 0/7905 [00:00<?, ?it/s]
# 2022-06-20 09:28:00,556 - SoPCACube - INFO - Gene matched:1794, not matched:0
# 2022-06-20 09:28:00,838 - Train - INFO - Data check before training start
# 2022-06-20 09:28:00,946 - Train - INFO - Data check passed, data path /content/drive/MyDrive/project/SoCube/embedding/20220620-092548-671/traindata
# 2022-06-20 09:28:00,948 - Train - INFO - Model ID: 20220620-092800-632
# 2022-06-20 09:28:01,083 - Train - INFO - Shape is torch.Size([10, 42, 43])
#   0%|          | 0/100 [00:00<?, ?it/s]
